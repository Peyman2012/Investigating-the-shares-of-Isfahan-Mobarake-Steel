# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import io
import requests as rq
import dtale as dt

# %%
url='http://old.tsetmc.com/tsev2/data/Export-txt.aspx?t=i&a=1&b=0&i=46348559193224090' 
fopen=rq.get(url).content
df_folad=pd.read_csv(io.StringIO(fopen.decode("utf-8")),index_col="<DTYYYYMMDD>",parse_dates=True)

# %%
df_folad
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-10-30    S*Mobarakeh.Steel   5250.0  5400.0  5250.0   5350.0
# 2023-10-29    S*Mobarakeh.Steel   5170.0  5270.0  5160.0   5230.0
# 2023-10-28    S*Mobarakeh.Steel   5330.0  5330.0  5160.0   5200.0
# 2023-10-25    S*Mobarakeh.Steel   5330.0  5390.0  5320.0   5350.0
# 2023-10-24    S*Mobarakeh.Steel   5360.0  5400.0  5280.0   5320.0
# ...                         ...      ...     ...     ...      ...
# 2007-03-17    S*Mobarakeh.Steel   1896.0  1927.0  1896.0   1898.0
# 2007-03-14    S*Mobarakeh.Steel   1934.0  1966.0  1934.0   1934.0
# 2007-03-13    S*Mobarakeh.Steel   1976.0  1976.0  1915.0   1973.0
# 2007-03-12    S*Mobarakeh.Steel   1938.0  1938.0  1938.0   1938.0
# 2007-03-11    S*Mobarakeh.Steel   1900.0  1938.0  1900.0   1900.0
#
#                    <VALUE>      <VOL>  <OPENINT> <PER>  <OPEN>  <LAST>
# <DTYYYYMMDD>
# 2023-10-30    322140648670   60200487       3317     D  5230.0  5390.0
# ...

# %%
df_folad.groupby('<DTYYYYMMDD>').last().iloc[49]
# Out:
# <TICKER>     S*Mobarakeh.Steel
# <FIRST>                 1829.0
# <HIGH>                  1848.0
# <LOW>                   1813.0
# <CLOSE>                 1848.0
# <VALUE>             1232478002
# <VOL>                   677604
# <OPENINT>                  175
# <PER>                        D
# <OPEN>                  1850.0
# <LAST>                  1848.0
# Name: 2007-05-27 00:00:00, dtype: object

# %%
df_folad.index[:50]
# Out:
# DatetimeIndex(['2023-10-30', '2023-10-29', '2023-10-28', '2023-10-25',
#                '2023-10-24', '2023-10-23', '2023-10-22', '2023-10-21',
#                '2023-10-18', '2023-10-16', '2023-10-15', '2023-10-14',
#                '2023-10-11', '2023-10-10', '2023-10-09', '2023-10-08',
#                '2023-10-07', '2023-10-04', '2023-10-02', '2023-10-01',
#                '2023-09-30', '2023-09-27', '2023-09-26', '2023-09-25',
#                '2023-09-23', '2023-09-20', '2023-09-19', '2023-09-18',
#                '2023-09-17', '2023-09-13', '2023-09-12', '2023-09-11',
#                '2023-09-10', '2023-09-09', '2023-09-05', '2023-09-04',
#                '2023-09-03', '2023-09-02', '2023-08-30', '2023-08-29',
#                '2023-08-28', '2023-08-27', '2023-08-26', '2023-08-23',
#                '2023-08-22', '2023-08-21', '2023-08-20', '2023-08-19',
#                '2023-08-16', '2023-08-15'],
#               dtype='datetime64[ns]', name='<DTYYYYMMDD>', freq=None)

# %%
df_folad_day50=df_folad[:50]
df_folad_day50
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-10-30    S*Mobarakeh.Steel   5250.0  5400.0  5250.0   5350.0
# 2023-10-29    S*Mobarakeh.Steel   5170.0  5270.0  5160.0   5230.0
# 2023-10-28    S*Mobarakeh.Steel   5330.0  5330.0  5160.0   5200.0
# 2023-10-25    S*Mobarakeh.Steel   5330.0  5390.0  5320.0   5350.0
# 2023-10-24    S*Mobarakeh.Steel   5360.0  5400.0  5280.0   5320.0
# 2023-10-23    S*Mobarakeh.Steel   5380.0  5460.0  5350.0   5390.0
# 2023-10-22    S*Mobarakeh.Steel   5300.0  5440.0  5300.0   5370.0
# 2023-10-21    S*Mobarakeh.Steel   5210.0  5240.0  5180.0   5210.0
# 2023-10-18    S*Mobarakeh.Steel   5240.0  5280.0  5190.0   5230.0
# 2023-10-16    S*Mobarakeh.Steel   5200.0  5290.0  5200.0   5240.0
# 2023-10-15    S*Mobarakeh.Steel   5120.0  5250.0  5110.0   5180.0
# 2023-10-14    S*Mobarakeh.Steel   5220.0  5230.0  5050.0   5140.0
# 2023-10-11    S*Mobarakeh.Steel   5300.0  5300.0  5190.0   5220.0
# ...

# %%
df_folad_day50.groupby('<DTYYYYMMDD>').last().iloc[0]['<CLOSE>']
# Out:
# 5120.0

# %%
len(df_folad_day50)
# Out:
# 50

# %%
df_folad_day50.iloc[49]
# Out:
# <TICKER>     S*Mobarakeh.Steel
# <FIRST>                 5120.0
# <HIGH>                  5180.0
# <LOW>                   5080.0
# <CLOSE>                 5120.0
# <VALUE>           332716507350
# <VOL>                 64986507
# <OPENINT>                 2926
# <PER>                        D
# <OPEN>                  5170.0
# <LAST>                  5100.0
# Name: 2023-08-15 00:00:00, dtype: object

# %%
df_folad_day50[df_folad_day50['<CLOSE>']==5160.0]
# Out:
# Empty DataFrame
# Columns: [<TICKER>, <FIRST>, <HIGH>, <LOW>, <CLOSE>, <VALUE>, <VOL>, <OPENINT>, <PER>, <OPEN>, <LAST>]
# Index: []

# %%
df_folad_day50[49:50]
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-08-15    S*Mobarakeh.Steel   5120.0  5180.0  5080.0   5120.0
#
#                    <VALUE>     <VOL>  <OPENINT> <PER>  <OPEN>  <LAST>
# <DTYYYYMMDD>
# 2023-08-15    332716507350  64986507       2926     D  5170.0  5100.0

# %% [markdown]
# Time to buy or sell stocks

# %%
df_folad_day50['<OPEN>'][49]
# Out:
# 5170.0

# %%
folad_open_day50=df_folad_day50.iloc[49]['<OPEN>']

# %%
folad_close_day50=df_folad_day50.iloc[49]['<CLOSE>']

# %%
if folad_open_day50>folad_close_day50:
    print('Time to buy folad shares')
elif folad_open_day50<folad_close_day50:
    print('Time to sell folad shares')
# Out:
# Time to buy folad shares

# %%
df_folad_day10=df_folad[df_folad['<CLOSE>']>4500][:10]

# %%
df_folad_day10
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-10-30    S*Mobarakeh.Steel   5250.0  5400.0  5250.0   5350.0
# 2023-10-29    S*Mobarakeh.Steel   5170.0  5270.0  5160.0   5230.0
# 2023-10-28    S*Mobarakeh.Steel   5330.0  5330.0  5160.0   5200.0
# 2023-10-25    S*Mobarakeh.Steel   5330.0  5390.0  5320.0   5350.0
# 2023-10-24    S*Mobarakeh.Steel   5360.0  5400.0  5280.0   5320.0
# 2023-10-23    S*Mobarakeh.Steel   5380.0  5460.0  5350.0   5390.0
# 2023-10-22    S*Mobarakeh.Steel   5300.0  5440.0  5300.0   5370.0
# 2023-10-21    S*Mobarakeh.Steel   5210.0  5240.0  5180.0   5210.0
# 2023-10-18    S*Mobarakeh.Steel   5240.0  5280.0  5190.0   5230.0
# 2023-10-16    S*Mobarakeh.Steel   5200.0  5290.0  5200.0   5240.0
#
#                    <VALUE>      <VOL>  <OPENINT> <PER>  <OPEN>  <LAST>
# <DTYYYYMMDD>
# 2023-10-30    322140648670   60200487       3317     D  5230.0  5390.0
# ...

# %%
df_folad_day50[((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])>0)==True]
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-10-28    S*Mobarakeh.Steel   5330.0  5330.0  5160.0   5200.0
# 2023-10-24    S*Mobarakeh.Steel   5360.0  5400.0  5280.0   5320.0
# 2023-10-21    S*Mobarakeh.Steel   5210.0  5240.0  5180.0   5210.0
# 2023-10-18    S*Mobarakeh.Steel   5240.0  5280.0  5190.0   5230.0
# 2023-10-14    S*Mobarakeh.Steel   5220.0  5230.0  5050.0   5140.0
# 2023-10-11    S*Mobarakeh.Steel   5300.0  5300.0  5190.0   5220.0
# 2023-10-08    S*Mobarakeh.Steel   5260.0  5270.0  5080.0   5130.0
# 2023-10-07    S*Mobarakeh.Steel   5300.0  5350.0  5260.0   5290.0
# 2023-10-02    S*Mobarakeh.Steel   5280.0  5350.0  5250.0   5300.0
# 2023-10-01    S*Mobarakeh.Steel   5410.0  5430.0  5280.0   5310.0
# 2023-09-30    S*Mobarakeh.Steel   5510.0  5550.0  5340.0   5410.0
# 2023-09-27    S*Mobarakeh.Steel   5500.0  5540.0  5460.0   5500.0
# 2023-09-26    S*Mobarakeh.Steel   5560.0  5560.0  5500.0   5520.0
# ...

# %%
df_folad_day50[((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])>0)==False]
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-10-30    S*Mobarakeh.Steel   5250.0  5400.0  5250.0   5350.0
# 2023-10-29    S*Mobarakeh.Steel   5170.0  5270.0  5160.0   5230.0
# 2023-10-25    S*Mobarakeh.Steel   5330.0  5390.0  5320.0   5350.0
# 2023-10-23    S*Mobarakeh.Steel   5380.0  5460.0  5350.0   5390.0
# 2023-10-22    S*Mobarakeh.Steel   5300.0  5440.0  5300.0   5370.0
# 2023-10-16    S*Mobarakeh.Steel   5200.0  5290.0  5200.0   5240.0
# 2023-10-15    S*Mobarakeh.Steel   5120.0  5250.0  5110.0   5180.0
# 2023-10-10    S*Mobarakeh.Steel   5230.0  5290.0  5190.0   5240.0
# 2023-10-09    S*Mobarakeh.Steel   5080.0  5400.0  5080.0   5230.0
# 2023-10-04    S*Mobarakeh.Steel   5310.0  5360.0  5290.0   5300.0
# 2023-09-23    S*Mobarakeh.Steel   5550.0  5610.0  5550.0   5590.0
# 2023-09-19    S*Mobarakeh.Steel   5570.0  5620.0  5550.0   5600.0
# 2023-09-18    S*Mobarakeh.Steel   5550.0  5610.0  5530.0   5570.0
# ...

# %%
df_folad_day50['<SIGNAL>']=(df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])>0
# Out:
# C:\Users\peyman\AppData\Local\Temp\ipykernel_17284\2574348862.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_folad_day50['<SIGNAL>'].iloc[1]
# Out:
# False

# %%
for i in range(len(df_folad_day50['<SIGNAL>'])):
    if df_folad_day50['<SIGNAL>'].iloc[i] == True:
        df_folad_day50['<SIGNAL>'].iloc[i] = 'Buy'
    elif df_folad_day50['<SIGNAL>'].iloc[i] == False:
        df_folad_day50['<SIGNAL>'].iloc[i] = 'Sell'
# Out:
# C:\Users\peyman\AppData\Local\Temp\ipykernel_17284\587855003.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\peyman\AppData\Local\Temp\ipykernel_17284\587855003.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_folad_day50
# Out:
#                        <TICKER>  <FIRST>  <HIGH>   <LOW>  <CLOSE>  \
# <DTYYYYMMDD>
# 2023-10-30    S*Mobarakeh.Steel   5250.0  5400.0  5250.0   5350.0
# 2023-10-29    S*Mobarakeh.Steel   5170.0  5270.0  5160.0   5230.0
# 2023-10-28    S*Mobarakeh.Steel   5330.0  5330.0  5160.0   5200.0
# 2023-10-25    S*Mobarakeh.Steel   5330.0  5390.0  5320.0   5350.0
# 2023-10-24    S*Mobarakeh.Steel   5360.0  5400.0  5280.0   5320.0
# 2023-10-23    S*Mobarakeh.Steel   5380.0  5460.0  5350.0   5390.0
# 2023-10-22    S*Mobarakeh.Steel   5300.0  5440.0  5300.0   5370.0
# 2023-10-21    S*Mobarakeh.Steel   5210.0  5240.0  5180.0   5210.0
# 2023-10-18    S*Mobarakeh.Steel   5240.0  5280.0  5190.0   5230.0
# 2023-10-16    S*Mobarakeh.Steel   5200.0  5290.0  5200.0   5240.0
# 2023-10-15    S*Mobarakeh.Steel   5120.0  5250.0  5110.0   5180.0
# 2023-10-14    S*Mobarakeh.Steel   5220.0  5230.0  5050.0   5140.0
# 2023-10-11    S*Mobarakeh.Steel   5300.0  5300.0  5190.0   5220.0
# ...

# %% [markdown]
# Signal for stock

# %%
sell_folad=df_folad_day50[((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])>0)==False].count()[11]
print(f'count time sell : {sell_folad}')
# Out:
# count time sell : 27

# %%
sell2_folad=df_folad_day50[(((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])>0)==False) & ((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])!=0)].count()[11]    
print(f'count time sell withon ziro : {sell2_folad}')
# Out:
# count time sell withon ziro : 21

# %%
ziro_folad=df_folad_day50[((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])==0)].count()[11]
print(f'count ziro  : {ziro_folad}')
# Out:
# count ziro  : 6

# %%
buy_folad=df_folad_day50[((df_folad_day50['<OPEN>']-df_folad_day50['<CLOSE>'])>0)==True].count()[11]
print(f'count time buy : {buy_folad}')
# Out:
# count time buy : 23

# %%
new_df=pd.DataFrame({'Hight':df_folad_day50['<HIGH>'],'Low':df_folad_day50['<LOW>'],
                    'Close':df_folad_day50['<CLOSE>'],'Volume':df_folad_day50['<VALUE>'],'Open':df_folad_day50['<OPEN>']})

# %%
new_df
# Out:
#                Hight     Low   Close         Volume    Open
# <DTYYYYMMDD>
# 2023-10-30    5400.0  5250.0  5350.0   322140648670  5230.0
# 2023-10-29    5270.0  5160.0  5230.0   298969240230  5200.0
# 2023-10-28    5330.0  5160.0  5200.0   634709280980  5350.0
# 2023-10-25    5390.0  5320.0  5350.0   329141791540  5320.0
# 2023-10-24    5400.0  5280.0  5320.0   519055203910  5390.0
# 2023-10-23    5460.0  5350.0  5390.0   463064870970  5370.0
# 2023-10-22    5440.0  5300.0  5370.0   514261021560  5210.0
# 2023-10-21    5240.0  5180.0  5210.0   462595759440  5230.0
# 2023-10-18    5280.0  5190.0  5230.0   463799376820  5240.0
# 2023-10-16    5290.0  5200.0  5240.0   254318726760  5180.0
# 2023-10-15    5250.0  5110.0  5180.0   376248755790  5140.0
# 2023-10-14    5230.0  5050.0  5140.0   357513300850  5220.0
# 2023-10-11    5300.0  5190.0  5220.0   254034855800  5240.0
# 2023-10-10    5290.0  5190.0  5240.0   304420550580  5230.0
# ...

# %%
ndf_folad=np.flip(np.array(new_df))

# %%
new_df['Diff']=new_df['Open'] - new_df['Close']

# %%
a=[]
for j in range(50):
    j=0
    a.append(j)
new_df['Buy']=a
new_df['Sell']=a

# %%
folad_buy=[]
for i in range(len(new_df)):
    if (new_df['Diff'].iloc[i]>0)==True:
        if new_df['Diff'].iloc[i]>0:
            folad_buy.append(new_df['Diff'].iloc[i])
    elif (new_df['Diff'].iloc[i]>0)==False:
        v=0
        folad_buy.append(v)

# %%
folad_sell=[]
for i in range(len(new_df)):
    if (new_df['Diff'].iloc[i]>=0)==False:
        if new_df['Diff'].iloc[i]<0:
            folad_sell.append(new_df['Diff'].iloc[i])
    elif (new_df['Diff'].iloc[i]>=0)==True:
        v=0
        folad_sell.append(v)

# %%
new_df['Buy']=folad_buy
new_df['Sell']=folad_sell

# %%
new_df
# Out:
#                Hight     Low   Close         Volume    Open   Diff    Buy  \
# <DTYYYYMMDD>
# 2023-10-30    5400.0  5250.0  5350.0   322140648670  5230.0 -120.0    0.0
# 2023-10-29    5270.0  5160.0  5230.0   298969240230  5200.0  -30.0    0.0
# 2023-10-28    5330.0  5160.0  5200.0   634709280980  5350.0  150.0  150.0
# 2023-10-25    5390.0  5320.0  5350.0   329141791540  5320.0  -30.0    0.0
# 2023-10-24    5400.0  5280.0  5320.0   519055203910  5390.0   70.0   70.0
# 2023-10-23    5460.0  5350.0  5390.0   463064870970  5370.0  -20.0    0.0
# 2023-10-22    5440.0  5300.0  5370.0   514261021560  5210.0 -160.0    0.0
# 2023-10-21    5240.0  5180.0  5210.0   462595759440  5230.0   20.0   20.0
# 2023-10-18    5280.0  5190.0  5230.0   463799376820  5240.0   10.0   10.0
# 2023-10-16    5290.0  5200.0  5240.0   254318726760  5180.0  -60.0    0.0
# 2023-10-15    5250.0  5110.0  5180.0   376248755790  5140.0  -40.0    0.0
# ...

# %%
plt.plot(ndf_folad)
plt.show()

# %%
df_day50=[sell_folad,buy_folad]
name_df=['Sell','Buy']

# %%
plt.title('The percentage of stock buy and sell signals')
plt.pie(df_day50,labels=name_df,autopct='%.0f%%')
plt.show()

# %%
df_day50=[sell2_folad,buy_folad,ziro_folad]
name_df=['Sell','Buy','Ziro']

# %%
plt.title('The percentage of stock buy and sell signals')
plt.pie(df_day50,labels=name_df,autopct='%.0f%%')
plt.show()

# %% [markdown]
# Investigating the profit or loss of shares

# %%
new_df.describe()
# Out:
#              Hight          Low        Close        Volume         Open  \
# count    50.000000    50.000000    50.000000  5.000000e+01    50.000000
# mean   5440.000000  5307.200000  5368.600000  5.133630e+11  5365.000000
# std     210.499891   196.115751   203.900836  1.996174e+11   205.815947
# min    5050.000000  4950.000000  5000.000000  2.540349e+11  5000.000000
# 25%    5282.500000  5160.000000  5220.000000  3.637576e+11  5212.500000
# 50%    5415.000000  5285.000000  5350.000000  4.629223e+11  5335.000000
# 75%    5610.000000  5507.500000  5570.000000  6.228151e+11  5570.000000
# max    5800.000000  5590.000000  5680.000000  1.282123e+12  5680.000000
#
#              Diff         Buy        Sell
# count   50.000000   50.000000   50.000000
# mean    -3.600000   23.200000  -26.800000
# std     77.847575   38.515303   57.514506
# min   -280.000000    0.000000 -280.000000
# 25%    -27.500000    0.000000  -27.500000
# 50%      0.000000    0.000000    0.000000
# ...

# %%
f=[]
for i in range(len(new_df['Diff'])):
    if (new_df['Diff'].iloc[i])>0:
        f.append('Buy')
    elif (new_df['Diff'].iloc[i])==0:
        f.append('Ziro')
    elif (new_df['Diff'].iloc[i])<0:
        f.append('Sell')
new_df['Signal']=f

# %%
new_df
# Out:
#                Hight     Low   Close         Volume    Open   Diff    Buy  \
# <DTYYYYMMDD>
# 2023-10-30    5400.0  5250.0  5350.0   322140648670  5230.0 -120.0    0.0
# 2023-10-29    5270.0  5160.0  5230.0   298969240230  5200.0  -30.0    0.0
# 2023-10-28    5330.0  5160.0  5200.0   634709280980  5350.0  150.0  150.0
# 2023-10-25    5390.0  5320.0  5350.0   329141791540  5320.0  -30.0    0.0
# 2023-10-24    5400.0  5280.0  5320.0   519055203910  5390.0   70.0   70.0
# 2023-10-23    5460.0  5350.0  5390.0   463064870970  5370.0  -20.0    0.0
# 2023-10-22    5440.0  5300.0  5370.0   514261021560  5210.0 -160.0    0.0
# 2023-10-21    5240.0  5180.0  5210.0   462595759440  5230.0   20.0   20.0
# 2023-10-18    5280.0  5190.0  5230.0   463799376820  5240.0   10.0   10.0
# 2023-10-16    5290.0  5200.0  5240.0   254318726760  5180.0  -60.0    0.0
# 2023-10-15    5250.0  5110.0  5180.0   376248755790  5140.0  -40.0    0.0
# ...

# %%
plt.bar(range(len(new_df['Buy'])),new_df['Buy'])
plt.bar(range(len(-new_df['Sell'])),-new_df['Sell'])
# Out:
# <BarContainer object of 50 artists>

# %%
df_per=new_df['Close']//new_df['Close'].iloc[0]
date=df_per.index[1].strftime('%Y-%m-%d')
for i in range(len(df_per)):
    date=df_per.index[i].strftime('%Y-%m-%d')
    if df_per.iloc[i]>=1:
        print(f'The dividend in {date} days is equal to {df_per.iloc[i]}')
    elif df_per.iloc[i]<1:
        print(f'Unfortunately, the dividend in {date} days is equal to {df_per.iloc[i]}')
# Out:
# The dividend in 2023-10-30 days is equal to 1.0
# Unfortunately, the dividend in 2023-10-29 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-28 days is equal to 0.0
# The dividend in 2023-10-25 days is equal to 1.0
# Unfortunately, the dividend in 2023-10-24 days is equal to 0.0
# The dividend in 2023-10-23 days is equal to 1.0
# The dividend in 2023-10-22 days is equal to 1.0
# Unfortunately, the dividend in 2023-10-21 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-18 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-16 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-15 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-14 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-11 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-10 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-09 days is equal to 0.0
# Unfortunately, the dividend in 2023-10-08 days is equal to 0.0
# ...

# %%
descending=new_df['Close'][1:]-new_df['Close'].iloc[0]

# %%
for i in range(len(descending)):
    date=descending.index[i].strftime('%Y-%m-%d')
    if descending.iloc[i]>0:
        print(f'Loss or profit on {date} day is equal to {descending.iloc[i]} which is a loss ')
    elif descending.iloc[i]==0:
        print(f'Loss or profit on {date} day is equal to {descending.iloc[i]} which means that he did not make a profit or a loss')
    elif descending.iloc[i]<0:
        print(f'Loss or profit on {date} day is equal to {descending.iloc[i]} which is  profit')
# Out:
# Loss or profit on 2023-10-29 day is equal to -120.0 which is  profit
# Loss or profit on 2023-10-28 day is equal to -150.0 which is  profit
# Loss or profit on 2023-10-25 day is equal to 0.0 which means that he did not make a profit or a loss
# Loss or profit on 2023-10-24 day is equal to -30.0 which is  profit
# Loss or profit on 2023-10-23 day is equal to 40.0 which is a loss
# Loss or profit on 2023-10-22 day is equal to 20.0 which is a loss
# Loss or profit on 2023-10-21 day is equal to -140.0 which is  profit
# Loss or profit on 2023-10-18 day is equal to -120.0 which is  profit
# Loss or profit on 2023-10-16 day is equal to -110.0 which is  profit
# Loss or profit on 2023-10-15 day is equal to -170.0 which is  profit
# Loss or profit on 2023-10-14 day is equal to -210.0 which is  profit
# Loss or profit on 2023-10-11 day is equal to -130.0 which is  profit
# Loss or profit on 2023-10-10 day is equal to -110.0 which is  profit
# ...

# %%
df_des10to50=new_df['Close'][49] - new_df['Close'][0]
df_des10to50
# Out:
# -230.0

# %%
df_des=np.array(new_df['Close'])

# %%
df_des[1]
# Out:
# 5230.0

# %%
df_des[-50]
# Out:
# 5350.0

# %%
sub_df=df_des[1:]-df_des[:-1]
sub_c=[]
for i in sub_df:
    sub_c.append(-i)
s_df=np.array(sub_c)
s_df
# Out:
# array([ 120.,   30., -150.,   30.,  -70.,   20.,  160.,  -20.,  -10.,
#          60.,   40.,  -80.,  -20.,   10.,  100., -160.,  -10.,   -0.,
#         -10., -100.,  -90.,  -20.,  -20.,  -50.,   -0.,  -10.,   30.,
#          -0.,   10.,   -0.,   10.,  -20.,  -40.,  -70.,   10.,   70.,
#          10.,  -30.,   10.,   30.,   80.,  280.,  220.,   -0.,  -60.,
#          10.,   -0.,  -60.,  -10.])

# %%
plt.bar(range(len(s_df)),np.where(s_df>0,s_df,0),color='green')
plt.bar(range(len(s_df)),np.where(s_df<0,s_df,0),color='red')
# Out:
# <BarContainer object of 49 artists>

# %%
pct=new_df['Close'][::-1].pct_change()

# %%
new_df.pct_change()
# Out:
#                  Hight       Low     Close    Volume      Open
# <DTYYYYMMDD>
# 2023-10-30         NaN       NaN       NaN       NaN       NaN
# 2023-10-29   -0.024074 -0.017143 -0.022430 -0.071929 -0.005736
# 2023-10-28    0.011385  0.000000 -0.005736  1.122992  0.028846
# 2023-10-25    0.011257  0.031008  0.028846 -0.481429 -0.005607
# 2023-10-24    0.001855 -0.007519 -0.005607  0.576996  0.013158
# 2023-10-23    0.011111  0.013258  0.013158 -0.107870 -0.003711
# 2023-10-22   -0.003663 -0.009346 -0.003711  0.110559 -0.029795
# 2023-10-21   -0.036765 -0.022642 -0.029795 -0.100465  0.003839
# 2023-10-18    0.007634  0.001931  0.003839  0.002602  0.001912
# 2023-10-16    0.001894  0.001927  0.001912 -0.451662 -0.011450
# 2023-10-15   -0.007561 -0.017308 -0.011450  0.479438 -0.007722
# 2023-10-14   -0.003810 -0.011742 -0.007722 -0.049795  0.015564
# 2023-10-11    0.013384  0.027723  0.015564 -0.289439  0.003831
# 2023-10-10   -0.001887  0.000000  0.003831  0.198342 -0.001908
# ...

# %%
pct.plot(legend=True,grid=True)
# Out:
# <Axes: xlabel='<DTYYYYMMDD>'>

# %%
new_df.plot(x="Close",y="Open",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Close', ylabel='Open'>

# %%
new_df.pct_change().plot(x="Close",y="Open",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Close', ylabel='Open'>

# %%
new_df.pct_change().plot(x="Open",y="Close",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Open', ylabel='Close'>

# %%
new_df.pct_change().plot(x="Hight",y="Low",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Hight', ylabel='Low'>

# %%
new_df.pct_change().plot(x="Close",y="Low",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Close', ylabel='Low'>

# %%
new_df.pct_change().plot(x="Close",y="Hight",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Close', ylabel='Hight'>

# %%
new_df.pct_change().plot(x="Open",y="Low",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Open', ylabel='Low'>

# %%
new_df.pct_change().plot(x="Close",y="Hight",figsize=(16,6) , kind="scatter",grid=True,colorbar=True)
# Out:
# <Axes: xlabel='Close', ylabel='Hight'>

# %% [markdown]
# github:  https://github.com/Peyman2012/Investigating-the-shares-of-Isfahan-Mobarake-Steel
